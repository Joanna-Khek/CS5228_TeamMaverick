# %% [markdown]
# # Data Engineering for Auxiliary Data

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import os
from pathlib import Path

import pandas as pd
import numpy as np

from geopy import distance
from src.preprocessing import update_data

# %%
def get_nearest_y(X, y):
    """
    input:
        X - a list of tuples representing (lat, lng)
        y - a list of tuples representing (lat, lng)
    return:
        distance_to_nearest - the distance from X to the closest y (in meters)
        index_of_nearest - the index of the closest y from X
    """
    distance_to_nearest = []
    index_of_nearest = []

    for point_x in X:
        distance_to_y = []

        for point_y in y:
            distance_to_y.append(distance.distance(point_x, point_y).meters)

        distance_to_y = np.array(distance_to_y)
        min_distance = np.min(distance_to_y, axis=0)
        min_index = np.argmin(distance_to_y, axis=0)

        distance_to_nearest.append(min_distance)
        index_of_nearest.append(min_index)

    return distance_to_nearest, index_of_nearest


def get_nearest_distances(df_X, df_y):

    # Zip the lat and lng into tuples
    X_coords = df_X[['lat', 'lng']].apply(tuple, axis=1)
    y_coords = df_y[['lat', 'lng']].apply(tuple, axis=1)

    distance_result, index_result = get_nearest_y(X_coords, y_coords)
    return distance_result, index_result

# %%
data_dir = Path("./raw_data/")
aux_data_dir = Path("./raw_data/auxiliary-data/")

# %%
def generate_auxiliary_data(df):
    
    df_aux = pd.DataFrame(index=df.index)
    df_aux['lat'] = df['lat']
    df_aux['lng'] = df['lng']

    # MRT
    df_sg_mrt_stations = pd.read_csv(Path(aux_data_dir, "sg-mrt-stations.csv"))
    distance_mrt, index_mrt = get_nearest_distances(df_aux, df_sg_mrt_stations)
    df_aux['dist_meters_to_nearest_mrt'] = distance_mrt
    df_aux['nearest_mrt_code'] = list(df_sg_mrt_stations.iloc[index_mrt]['code'])
    df_aux['nearest_mrt_line'] = list(df_sg_mrt_stations.iloc[index_mrt]['line'])

    # Shopping mall
    df_sg_shopping_malls = pd.read_csv(Path(aux_data_dir, "sg-shopping-malls.csv"))
    distance_mall, index_mall = get_nearest_distances(df_aux, df_sg_shopping_malls)
    df_aux['dist_meters_to_nearest_mall'] = distance_mall
    df_aux['nearest_mall_index'] = index_mall

    # Commercial centres
    df_sg_commercial_centres = pd.read_csv(Path(aux_data_dir, "sg-commerical-centres.csv"))
    distance_commercial, index_commercial = get_nearest_distances(df_aux, df_sg_commercial_centres)
    df_aux['dist_meters_to_nearest_commercial_centre'] = distance_commercial
    df_aux['nearest_commercial_centre_index'] = index_commercial

    # Primary schools
    df_sg_pri_sch = pd.read_csv(Path(aux_data_dir, "sg-primary-schools.csv"))
    distance_pri_sch, index_pri_sch = get_nearest_distances(df_aux, df_sg_pri_sch)
    df_aux['dist_meters_to_nearest_primary_school'] = distance_pri_sch
    df_aux['nearest_primary_school_index'] = index_pri_sch

    # Secondary schools
    df_sg_sec_sch = pd.read_csv(Path(aux_data_dir, "sg-secondary-schools.csv"))
    distance_sec_sch, index_sec_sch = get_nearest_distances(df_aux, df_sg_sec_sch)
    df_aux['dist_meters_to_nearest_secondary_school'] = distance_sec_sch
    df_aux['nearest_secondary_school_index'] = index_sec_sch

    return df_aux

# %% [markdown]
# ## Generate the auxiliary features for nearest community facilities

# %% [markdown]
# This takes around 8 seconds per 100 records.
#
# For the entire training and test set, it takes around 40 minutes (_Probably have some room to optimize this_)

# %%
df_train = pd.read_csv(Path(data_dir, "train.csv"))
df_test = pd.read_csv(Path(data_dir, "test.csv"))

# Clean the records with dirty lat, lng identified in EDA
update_data(df_train)
update_data(df_test)
# Out:
#       listing_id                                             title  \
# 0         777912               1 bed condo for sale in the gazania
# 1         936612           3 bed condo for sale in vue 8 residence
# 2         995264                      1 bed condo for sale in icon
# 3         477435  hdb flat for sale in 812b choa chu kang avenue 7
# 4         222529          hdb flat for sale in 204 toa payoh north
# ...          ...                                               ...
# 6995      289879           5 bed house for sale in paradise island
# 6996      396404            5 bed house for sale in orchid village
# 6997      620343                3 bed condo for sale in the avenir
# 6998      364805           hdb flat for sale in 31 marine crescent
# 6999      915621                   3 bed condo for sale in riviere
#
#                                                 address  \
# 0                                      17 how sun drive
# 1                                  95 pasir ris heights
# 2                                      10 gopeng street
# 3     bukit batok / bukit panjang / choa chu kang (d23)
# 4                           balestier / toa payoh (d12)
# ...                                                 ...
# 6995                                    paradise island
# 6996                                        vanda drive
# 6997                               8 river valley close
# 6998                   east coast / marine parade (d15)
# 6999                                  3 jiak kim street
#
#               property_name        property_type             tenure  \
# 0               the gazania                condo           freehold
# 1           vue 8 residence                Condo  99-year leasehold
# 2                      icon                condo  99-year leasehold
# 3         keat hong colours                  Hdb  99-year leasehold
# 4          toa payoh spring          hdb 4 rooms  99-year leasehold
# ...                     ...                  ...                ...
# 6995        paradise island             bungalow  99-year leasehold
# 6996         orchid village  Semi-Detached House           freehold
# 6997             the avenir                Condo           freehold
# 6998  marine crescent ville                  hdb  99-year leasehold
# 6999                riviere                condo  99-year leasehold
#
#       built_year  num_beds  num_baths  size_sqft floor_level   furnishing  \
# 0         2022.0       1.0        1.0        463         NaN  unfurnished
# 1         2017.0       3.0        3.0       1033        high  unspecified
# 2         2007.0       1.0        1.0        570         NaN        fully
# 3         2017.0       3.0        2.0       1216         NaN  unspecified
# 4         1973.0       3.0        2.0        936         NaN  unspecified
# ...          ...       ...        ...        ...         ...          ...
# 6995      2009.0       5.0        6.0       8000         NaN  unspecified
# 6996      2010.0       5.0        7.0       6974         NaN  unspecified
# 6997      2025.0       3.0        2.0       1141         NaN      partial
# 6998      1975.0       3.0        1.0        818         NaN  unspecified
# 6999      2023.0       3.0        3.0       1507         NaN  unspecified
#
#           available_unit_types  total_num_units  \
# 0     studio, 1, 2, 3, 4, 5 br            250.0
# 1     studio, 1, 2, 3, 4, 5 br            463.0
# 2           studio, 1, 2, 3 br            646.0
# 3             1, 2, 3, 4, 5 br            968.0
# 4                1, 2, 3, 4 br              NaN
# ...                        ...              ...
# 6995          4, 5, 6, 7, 8 br             29.0
# 6996          4, 5, 6, 7, 8 br              NaN
# 6997  studio, 1, 2, 3, 4, 5 br            376.0
# 6998             1, 2, 3, 4 br              NaN
# 6999          1, 2, 3, 4, 5 br            455.0
#
#                                    property_details_url       lat         lng  \
# 0     https://www.99.co/singapore/condos-apartments/...  1.344334  103.878690
# 1     https://www.99.co/singapore/condos-apartments/...  1.380281  103.943878
# 2     https://www.99.co/singapore/condos-apartments/...  1.294668  103.850074
# 3     https://www.99.co/singapore/hdb/keat-hong-colo...  1.373120  103.746094
# 4     https://www.99.co/singapore/hdb/toa-payoh-spri...  1.341468  103.849047
# ...                                                 ...       ...         ...
# 6995  https://www.99.co/singapore/houses/paradise-is...  1.249534  103.844281
# 6996  https://www.99.co/singapore/houses/orchid-vill...  1.332492  103.800004
# 6997  https://www.99.co/singapore/condos-apartments/...  1.294106  103.836735
# 6998  https://www.99.co/singapore/hdb/marine-crescen...  1.303736  103.911438
# 6999  https://www.99.co/singapore/condos-apartments/...  1.302770  103.869435
#
#       elevation           subzone     planning_area
# 0             0  upper paya lebar         serangoon
# 1             0    pasir ris west         pasir ris
# 2             0        bras basah            museum
# 3             0         keat hong     choa chu kang
# 4             0          braddell         toa payoh
# ...         ...               ...               ...
# 6995          0           sentosa  southern islands
# 6996          0         hillcrest       bukit timah
# 6997          0  institution hill      river valley
# 6998          0     marine parade     marine parade
# 6999          0       tanjong rhu           kallang
#
# [7000 rows x 20 columns]

# %%
df_train_aux = generate_auxiliary_data(df_train)
df_train_aux

# %%
df_test_aux = generate_auxiliary_data(df_test)
df_test_aux
# Out:
#            lat         lng  dist_meters_to_nearest_mrt nearest_mrt_code  \
# 0     1.344334  103.878690                  261.672594             cc12
# 1     1.380281  103.943878                 1001.264290              ew1
# 2     1.294668  103.850074                  251.350375              cc2
# 3     1.373120  103.746094                 1367.323437              ns4
# 4     1.341468  103.849047                  273.515978             ns18
# ...        ...         ...                         ...              ...
# 6995  1.249534  103.844281                 2992.831027             ew15
# 6996  1.332492  103.800004                  389.150989              dt7
# 6997  1.294106  103.836735                  729.462991             ns23
# 6998  1.303736  103.911438                 1920.516380              ew6
# 6999  1.302770  103.869435                  656.923572              cc6
#
#      nearest_mrt_line  dist_meters_to_nearest_mall  nearest_mall_index  \
# 0                  cc                   985.874655                 110
# 1                  ew                   281.936655                  86
# 2                  cc                   212.685809                   7
# 3                  ns                   501.765017                 133
# 4                  ns                  1009.165929                  21
# ...               ...                          ...                 ...
# 6995               ew                  2885.355551                 142
# 6996               dt                   965.822466                 156
# 6997               ns                   532.653630                  17
# 6998               ew                   729.699795                  76
# 6999               cc                   382.422444                  74
#
#       dist_meters_to_nearest_commercial_centre  \
# 0                                  1044.920854
# 1                                  1435.511147
# 2                                   157.232207
# 3                                  4504.563672
# 4                                   985.918261
# ...                                        ...
# 6995                               4272.197274
# 6996                               3081.254261
# 6997                               1527.283142
# 6998                               2555.480675
# 6999                               2252.831259
#
#       nearest_commercial_centre_index  dist_meters_to_nearest_primary_school  \
# 0                                  31                             341.056419
# 1                                  15                            1078.101901
# 2                                  37                             343.739518
# 3                                   1                             702.141804
# 4                                  32                             418.716281
# ...                               ...                                    ...
# 6995                                0                            2946.737990
# 6996                               28                             743.925796
# 6997                               37                            1444.051119
# 6998                               30                             147.133722
# 6999                               37                            1355.591932
#
#       nearest_primary_school_index  dist_meters_to_nearest_secondary_school  \
# 0                               88                               343.615356
# 1                               93                              1396.610341
# 2                               22                               562.723759
# 3                               34                              1062.566045
# 4                               79                               360.715437
# ...                            ...                                      ...
# 6995                            20                              3861.603350
# 6996                           126                               322.085215
# 6997                             3                               866.888397
# 6998                           148                               749.160547
# 6999                           139                              1453.624324
#
#       nearest_secondary_school_index
# 0                                 71
# 1                                 55
# 2                                109
# 3                                122
# 4                                  9
# ...                              ...
# 6995                              29
# 6996                              79
# 6997                              89
# 6998                              25
# 6999                              41
#
# [7000 rows x 13 columns]

# %% [markdown]
# ### Save the results

# %%
df_train_aux = df_train_aux.drop(['lat', 'lng'], axis=1)

# %%
df_train_aux.describe()

# %%
df_train_aux.to_csv("raw_data/train_auxiliary_data.csv")

# %%
df_test_aux = df_test_aux.drop(['lat', 'lng'], axis=1)

# %%
df_test_aux.describe()
# Out:
#        dist_meters_to_nearest_mrt  dist_meters_to_nearest_mall  \
# count                 7000.000000                  7000.000000
# mean                   787.154986                   785.993608
# std                    550.611829                   524.112192
# min                      5.257545                     0.000000
# 25%                    400.608170                   398.022578
# 50%                    656.923572                   670.208758
# 75%                   1014.802226                  1027.768950
# max                   3983.074990                  3897.147058
#
#        nearest_mall_index  dist_meters_to_nearest_commercial_centre  \
# count         7000.000000                               7000.000000
# mean            83.415286                               1924.896385
# std             44.386761                               1070.695689
# min              2.000000                                 93.334138
# 25%             51.000000                               1173.475276
# 50%             86.000000                               1681.479925
# 75%            117.000000                               2423.052923
# max            164.000000                               5574.454058
#
#        nearest_commercial_centre_index  dist_meters_to_nearest_primary_school  \
# count                      7000.000000                            7000.000000
# mean                         21.052714                             735.360130
# std                          11.970385                             534.888693
# min                           0.000000                               0.000000
# 25%                           9.000000                             365.638318
# 50%                          26.000000                             603.752052
# 75%                          30.000000                             996.729477
# max                          37.000000                            4009.378093
#
#        nearest_primary_school_index  dist_meters_to_nearest_secondary_school  \
# count                   7000.000000                              7000.000000
# mean                      75.750000                               826.887814
# std                       53.928687                               617.764963
# min                        0.000000                                67.393276
# 25%                       22.000000                               434.994799
# 50%                       70.000000                               675.767381
# 75%                      126.000000                              1029.960484
# max                      179.000000                              4442.112669
#
#        nearest_secondary_school_index
# count                     7000.000000
# mean                        65.829429
# std                         41.862228
# min                          0.000000
# 25%                         29.000000
# 50%                         71.000000
# 75%                        100.000000
# max                        147.000000

# %%
df_test_aux.to_csv("raw_data/test_auxiliary_data.csv")
