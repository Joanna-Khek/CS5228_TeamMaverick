# %% [markdown]
# # XGBoost

# %%
import pandas as pd

# %% [markdown]
# ## Data Import

# %%
df_train = pd.read_csv('raw_data/train.csv')
df_test = pd.read_csv('raw_data/test.csv')

# %% [markdown]
# Import auxiliary data and select useful columns

# %%
df_train_aux = pd.read_csv('raw_data/train_auxiliary_data.csv', index_col=0)
df_test_aux = pd.read_csv('raw_data/test_auxiliary_data.csv', index_col=0)

useful_columns = ['nearest_mrt_line']
df_train_aux = df_train_aux[useful_columns]
df_test_aux = df_test_aux[useful_columns]

# %% [markdown]
# Join the auxiliary data to the dataset

# %%
df_train = df_train.join(df_train_aux)
df_test = df_test.join(df_test_aux)

# %% [markdown]
# ## Data pre-processing

# %% [markdown]
# Clean dirty values and drop outliers identified in EDA.

# %%
from src.preprocessing import clean_property_type, fill_missing_values, update_data, drop_outliers

def data_cleaning(df):
    df_clean = df.copy()
    df_clean = clean_property_type(df_clean)
    df_clean = fill_missing_values(df_clean)
    df_clean = update_data(df_clean)
    return df_clean

# %%
df_train = data_cleaning(df_train)
df_train = drop_outliers(df_train)

df_test = data_cleaning(df_test)

# %% [markdown]
# Drop unused columns from the original dataset.

# %%
from src.preprocessing import drop_columns
df_train = drop_columns(df_train)
df_test = drop_columns(df_test)

# %% [markdown]
# ### Separate into X and y DataFrames

# %%
y_train = df_train['price']
X_train = df_train.drop('price', axis=1)
X_test = df_test

# %% [markdown]
# ## Encoding

# %% [markdown]
# Check the number of unique values for each categorical feature.

# %%
X_train.describe(include='object')
# Out:
#        property_type             tenure planning_area nearest_mrt_line
# count          20242              20242         20242            20242
# unique            15                 11            43                8
# top            condo  99-year leasehold   bukit timah               dt
# freq            9642              12842          1323             4494

# %% [markdown]
# For the numerical variables, the order of magnitude varies, so normalization is carried out.

# %%
X_train.describe()
# Out:
#         built_year      num_beds     num_baths     size_sqft           lat  \
# count  20242.00000  20242.000000  20242.000000  20242.000000  20242.000000
# mean    2010.78678      3.118615      2.631311   1711.291374      1.339994
# std       15.66283      1.280566      1.461078   1850.382364      0.046302
# min     1963.00000      1.000000      1.000000     65.000000      1.239621
# 25%     2000.00000      2.000000      2.000000    807.000000      1.307313
# 50%     2017.00000      3.000000      2.000000   1119.000000      1.328225
# 75%     2023.00000      4.000000      3.000000   1528.000000      1.371107
# max     2028.00000     10.000000     10.000000  30000.000000      1.461582
#
#                 lng
# count  20242.000000
# mean     103.843159
# std        0.054085
# min      103.685206
# 25%      103.806671
# 50%      103.841572
# 75%      103.880155
# max      103.997510

# %%
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, minmax_scale
from category_encoders.target_encoder import TargetEncoder
from sklearn.compose import make_column_transformer

# cat_vars = list(X_train.select_dtypes('object'))
num_vars = list(X_train.select_dtypes('number'))

ct = make_column_transformer(
    (MinMaxScaler(), num_vars),
    (TargetEncoder(), ['planning_area']),
    (OneHotEncoder(max_categories=3), ['tenure']),
    (OneHotEncoder(), ['property_type', 'nearest_mrt_line']),
    remainder='passthrough',
    verbose_feature_names_out=False
)

# Fit the column transformer
ct.fit(X_train, minmax_scale(y_train))
# Out:
# c:\Users\chikk\AppData\Local\Programs\Python\Python310\lib\site-packages\category_encoders\target_encoder.py:92: FutureWarning: Default parameter min_samples_leaf will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
#   warnings.warn("Default parameter min_samples_leaf will change in version 2.6."
# c:\Users\chikk\AppData\Local\Programs\Python\Python310\lib\site-packages\category_encoders\target_encoder.py:97: FutureWarning: Default parameter smoothing will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
#   warnings.warn("Default parameter smoothing will change in version 2.6."
# c:\Users\chikk\AppData\Local\Programs\Python\Python310\lib\site-packages\category_encoders\target_encoder.py:92: FutureWarning: Default parameter min_samples_leaf will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
#   warnings.warn("Default parameter min_samples_leaf will change in version 2.6."
# c:\Users\chikk\AppData\Local\Programs\Python\Python310\lib\site-packages\category_encoders\target_encoder.py:97: FutureWarning: Default parameter smoothing will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
#   warnings.warn("Default parameter smoothing will change in version 2.6."
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('minmaxscaler', MinMaxScaler(),
#                                  ['built_year', 'num_beds', 'num_baths',
#                                   'size_sqft', 'lat', 'lng']),
#                                 ('targetencoder', TargetEncoder(),
#                                  ['planning_area']),
#                                 ('onehotencoder-1',
#                                  OneHotEncoder(max_categories=3), ['tenure']),
#                                 ('onehotencoder-2', OneHotEncoder(),
#                                  ['property_type', 'nearest_mrt_line'])],
#                   verbose_feature_names_out=False)

# %%
# Transform the features
X_train = ct.transform(X_train)
X_test = ct.transform(X_test)

# %% [markdown]
# ## Fitting model with Cross Validation

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

param_grid = {
    'max_depth' : [2, 4, 6],
    'n_estimators' : [50, 100, 200]
}

model = GridSearchCV(xgb.XGBRegressor(), param_grid, scoring='neg_root_mean_squared_error')
model.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     gamma=None, gpu_id=None, grow_policy=None,
#                                     importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_bin=None,
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None, n_estimators=100,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     predictor=None, random_state=None,
#                                     reg_alpha=None, reg_lambda=None, ...),
#              param_grid={'max_depth': [2, 4, 6],
#                          'n_estimators': [50, 100, 200]},
#              scoring='neg_root_mean_squared_error')

# %%
print(f'Best parameters: {model.best_params_}')
print(f'Best score: {model.best_score_}')
# Out:
# Best parameters: {'max_depth': 4, 'n_estimators': 200}
# Best score: -2002239.6168093786

# %%
cv_results = pd.DataFrame(model.cv_results_).T
cv_results
# Out:
#                                                        0  \
# mean_fit_time                                   0.099135
# std_fit_time                                    0.005592
# mean_score_time                                 0.003391
# std_score_time                                  0.000798
# param_max_depth                                        2
# param_n_estimators                                    50
# params              {'max_depth': 2, 'n_estimators': 50}
# split0_test_score                        -2209881.698343
# split1_test_score                        -3618204.626466
# split2_test_score                        -1754617.626286
# split3_test_score                        -2284089.221765
# split4_test_score                        -2162813.594043
# mean_test_score                          -2405921.353381
# std_test_score                             633435.596793
# rank_test_score                                        9
#
#                                                         1  \
# mean_fit_time                                    0.163033
# std_fit_time                                     0.004737
# mean_score_time                                  0.003202
# std_score_time                                   0.000406
# param_max_depth                                         2
# param_n_estimators                                    100
# params              {'max_depth': 2, 'n_estimators': 100}
# split0_test_score                         -2012397.279344
# split1_test_score                         -3479456.286007
# split2_test_score                         -1720789.998773
# split3_test_score                         -2047971.682927
# split4_test_score                         -2057105.519309
# mean_test_score                           -2263544.153272
# std_test_score                              620513.906146
# rank_test_score                                         8
#
#                                                         2  \
# mean_fit_time                                    0.301007
# std_fit_time                                     0.004639
# mean_score_time                                  0.003093
# std_score_time                                   0.000201
# param_max_depth                                         2
# param_n_estimators                                    200
# params              {'max_depth': 2, 'n_estimators': 200}
# split0_test_score                         -1933960.628124
# split1_test_score                         -3357259.187588
# split2_test_score                         -1717236.003431
# split3_test_score                         -1944167.538429
# split4_test_score                         -2009529.221674
# mean_test_score                           -2192430.515849
# std_test_score                              590682.610438
# rank_test_score                                         7
#
#                                                        3  \
# mean_fit_time                                   0.137438
# std_fit_time                                    0.000871
# mean_score_time                                 0.002992
# std_score_time                                       0.0
# param_max_depth                                        4
# param_n_estimators                                    50
# params              {'max_depth': 4, 'n_estimators': 50}
# split0_test_score                        -2305233.107946
# split1_test_score                        -3067535.097435
# split2_test_score                        -1609881.722326
# split3_test_score                        -1598577.357559
# split4_test_score                        -1902793.682366
# mean_test_score                          -2096804.193526
# std_test_score                             549313.144144
# rank_test_score                                        6
#
#                                                         4  \
# mean_fit_time                                    0.271983
# std_fit_time                                     0.009672
# mean_score_time                                   0.00359
# std_score_time                                   0.000489
# param_max_depth                                         4
# param_n_estimators                                    100
# params              {'max_depth': 4, 'n_estimators': 100}
# split0_test_score                         -2317314.213599
# split1_test_score                         -2947431.601678
# split2_test_score                         -1616575.864326
# split3_test_score                         -1536207.067766
# split4_test_score                         -1872755.478514
# mean_test_score                           -2058056.845177
# std_test_score                              521492.297874
# rank_test_score                                         5
#
#                                                         5  \
# mean_fit_time                                     0.53808
# std_fit_time                                     0.010341
# mean_score_time                                  0.003989
# std_score_time                                        0.0
# param_max_depth                                         4
# param_n_estimators                                    200
# params              {'max_depth': 4, 'n_estimators': 200}
# split0_test_score                          -2353199.90314
# split1_test_score                         -2780314.296117
# split2_test_score                         -1582554.810423
# split3_test_score                         -1485184.039827
# split4_test_score                          -1809945.03454
# mean_test_score                           -2002239.616809
# std_test_score                              491738.211232
# rank_test_score                                         1
#
#                                                        6  \
# mean_fit_time                                   0.207549
# std_fit_time                                    0.006757
# mean_score_time                                 0.002992
# std_score_time                                       0.0
# param_max_depth                                        6
# param_n_estimators                                    50
# params              {'max_depth': 6, 'n_estimators': 50}
# split0_test_score                         -2475544.05553
# split1_test_score                        -2730563.274457
# split2_test_score                        -1557670.966761
# split3_test_score                        -1745357.356593
# split4_test_score                        -1670481.762106
# mean_test_score                          -2035923.483089
# std_test_score                             473812.722949
# rank_test_score                                        4
#
#                                                         7  \
# mean_fit_time                                    0.383489
# std_fit_time                                     0.004886
# mean_score_time                                  0.003391
# std_score_time                                   0.000489
# param_max_depth                                         6
# param_n_estimators                                    100
# params              {'max_depth': 6, 'n_estimators': 100}
# split0_test_score                         -2466397.305862
# split1_test_score                         -2689128.634615
# split2_test_score                         -1541865.725865
# split3_test_score                         -1731712.732138
# split4_test_score                         -1649750.910042
# mean_test_score                           -2015771.061704
# std_test_score                              468128.312811
# rank_test_score                                         3
#
#                                                         8
# mean_fit_time                                    0.779743
# std_fit_time                                     0.026103
# mean_score_time                                  0.004787
# std_score_time                                   0.000399
# param_max_depth                                         6
# param_n_estimators                                    200
# params              {'max_depth': 6, 'n_estimators': 200}
# split0_test_score                         -2461569.619399
# split1_test_score                         -2685790.659181
# split2_test_score                         -1544985.113561
# split3_test_score                         -1709539.311081
# split4_test_score                         -1658512.961693
# mean_test_score                           -2012079.532983
# std_test_score                              467042.850755
# rank_test_score                                         2

# %% [markdown]
# ## Predictions

# %%
import joblib
# Save the model
joblib.dump(model, 'models/xgboost_model_with_aux_data.joblib')
# Out:
# ['models/xgboost_model_with_aux_data.joblib']

# %%
df_test.describe()
# Out:
#         built_year     num_beds    num_baths     size_sqft          lat  \
# count  7000.000000  7000.000000  7000.000000   7000.000000  7000.000000
# mean   2010.754571     3.085857     2.614714   1709.027000     1.339711
# std      15.537008     1.277779     1.456611   1860.113894     0.046020
# min    1963.000000     1.000000     1.000000     68.000000     1.239621
# 25%    2000.000000     2.000000     2.000000    797.000000     1.307069
# 50%    2016.000000     3.000000     2.000000   1119.000000     1.328282
# 75%    2023.000000     4.000000     3.000000   1528.000000     1.369892
# max    2028.000000    10.000000    10.000000  27500.000000     1.461582
#
#                lng
# count  7000.000000
# mean    103.843177
# std       0.054518
# min     103.686082
# 25%     103.806577
# 50%     103.842259
# 75%     103.879060
# max     103.997510

# %%
print("Generate predictions")
pred = model.predict(X_test)
print("predictions shape:", pred.shape)
# Out:
# Generate predictions
# predictions shape: (7000,)

# %%
df_submission = pd.read_csv("raw_data/example-submission.csv")
df_submission["Predicted"] = pred
df_submission
# Out:
#         Id     Predicted
# 0        0  1.153526e+06
# 1        1  1.418528e+06
# 2        2  1.143806e+06
# 3        3  7.396819e+05
# 4        4  5.575652e+05
# ...    ...           ...
# 6995  6995  1.874818e+07
# 6996  6996  1.242276e+07
# 6997  6997  3.462699e+06
# 6998  6998  4.405036e+05
# 6999  6999  3.692374e+06
#
# [7000 rows x 2 columns]

# %%
df_submission.to_csv("xgboost_submission.csv", index=0)
