# %% [markdown]
# # Data Engineering for Auxiliary Data

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import os
from pathlib import Path

import pandas as pd
import numpy as np

from geopy import distance
from src.preprocessing import update_data

# %%
def get_nearest_y(X, y):
    """
    input:
        X - a list of tuples representing (lat, lng)
        y - a list of tuples representing (lat, lng)
    return:
        distance_to_nearest - the distance from X to the closest y (in meters)
        index_of_nearest - the index of the closest y from X
    """
    distance_to_nearest = []
    index_of_nearest = []

    for point_x in X:
        distance_to_y = []

        for point_y in y:
            distance_to_y.append(distance.distance(point_x, point_y).meters)

        distance_to_y = np.array(distance_to_y)
        min_distance = np.min(distance_to_y, axis=0)
        min_index = np.argmin(distance_to_y, axis=0)

        distance_to_nearest.append(min_distance)
        index_of_nearest.append(min_index)

    return distance_to_nearest, index_of_nearest


def get_nearest_distances(df_X, df_y):

    # Zip the lat and lng into tuples
    X_coords = df_X[['lat', 'lng']].apply(tuple, axis=1)
    y_coords = df_y[['lat', 'lng']].apply(tuple, axis=1)

    distance_result, index_result = get_nearest_y(X_coords, y_coords)
    return distance_result, index_result

# %%
data_dir = Path("./raw_data/")
aux_data_dir = Path("./raw_data/auxiliary-data/")

# %%
def generate_auxiliary_data(df):
    
    df_aux = pd.DataFrame(index=df.index)
    df_aux['lat'] = df['lat']
    df_aux['lng'] = df['lng']

    # MRT
    df_sg_mrt_stations = pd.read_csv(Path(aux_data_dir, "sg-mrt-stations.csv"))
    distance_mrt, index_mrt = get_nearest_distances(df_aux, df_sg_mrt_stations)
    df_aux['dist_meters_to_nearest_mrt'] = distance_mrt
    df_aux['nearest_mrt_code'] = list(df_sg_mrt_stations.iloc[index_mrt]['code'])
    df_aux['nearest_mrt_line'] = list(df_sg_mrt_stations.iloc[index_mrt]['line'])

    # Shopping mall
    df_sg_shopping_malls = pd.read_csv(Path(aux_data_dir, "sg-shopping-malls.csv"))
    distance_mall, index_mall = get_nearest_distances(df_aux, df_sg_shopping_malls)
    df_aux['dist_meters_to_nearest_mall'] = distance_mall
    df_aux['nearest_mall_index'] = index_mall

    # Commercial centres
    df_sg_commercial_centres = pd.read_csv(Path(aux_data_dir, "sg-commerical-centres.csv"))
    distance_commercial, index_commercial = get_nearest_distances(df_aux, df_sg_commercial_centres)
    df_aux['dist_meters_to_nearest_commercial_centre'] = distance_commercial
    df_aux['nearest_commercial_centre_index'] = index_commercial

    # Primary schools
    df_sg_pri_sch = pd.read_csv(Path(aux_data_dir, "sg-primary-schools.csv"))
    distance_pri_sch, index_pri_sch = get_nearest_distances(df_aux, df_sg_pri_sch)
    df_aux['dist_meters_to_nearest_primary_school'] = distance_pri_sch
    df_aux['nearest_primary_school_index'] = index_pri_sch

    # Secondary schools
    df_sg_sec_sch = pd.read_csv(Path(aux_data_dir, "sg-secondary-schools.csv"))
    distance_sec_sch, index_sec_sch = get_nearest_distances(df_aux, df_sg_sec_sch)
    df_aux['dist_meters_to_nearest_secondary_school'] = distance_sec_sch
    df_aux['nearest_secondary_school_index'] = index_sec_sch

    return df_aux

# %% [markdown]
# ## Generate the auxiliary features for nearest community facilities

# %% [markdown]
# This takes around 8 seconds per 100 records.
#
# For the entire training and test set, it takes around 40 minutes (_Probably have some room to optimize this_)

# %%
df_train = pd.read_csv(Path(data_dir, "train.csv"))

# Clean the records with dirty lat, lng identified in EDA
update_data(df_train)
# Out:
#        listing_id                                              title  \
# 0          122881          hdb flat for sale in 866 yishun street 81
# 1          259374  hdb flat for sale in 506b serangoon north aven...
# 2          665422                 4 bed condo for sale in meyerhouse
# 3          857699               3 bed condo for sale in leedon green
# 4          216061                 2 bed condo for sale in one bernam
# ...           ...                                                ...
# 20249      345066              2 bed condo for sale in lentor modern
# 20250      868680                       2 bed condo for sale in mori
# 20251      928187  4 bed condo for sale in pullman residences newton
# 20252      135122       hdb flat for sale in 691d woodlands drive 73
# 20253      376579  4 bed condo for sale in pullman residences newton
#
#                                   address              property_name  \
# 0                sembawang / yishun (d27)       866 yishun street 81
# 1      hougang / punggol / sengkang (d19)       hdb-serangoon estate
# 2                          128 meyer road                 meyerhouse
# 3                       26 leedon heights               leedon green
# 4                         1 bernam street                 one bernam
# ...                                   ...                        ...
# 20249                      lentor central              lentor modern
# 20250                 223 guillemard road                       mori
# 20251                     18 dunearn road  pullman residences newton
# 20252         admiralty / woodlands (d25)            admiralty flora
# 20253                     18 dunearn road  pullman residences newton
#
#       property_type             tenure  built_year  num_beds  num_baths  \
# 0       hdb 4 rooms                NaN      1988.0       3.0        2.0
# 1               hdb  99-year leasehold      1992.0       4.0        2.0
# 2             condo           freehold      2022.0       4.0        6.0
# 3             Condo           freehold      2023.0       3.0        2.0
# 4             condo  99-year leasehold      2026.0       2.0        1.0
# ...             ...                ...         ...       ...        ...
# 20249         condo  99-year leasehold      2026.0       2.0        2.0
# 20250         Condo           freehold      2026.0       2.0        2.0
# 20251         condo           freehold      2023.0       4.0        4.0
# 20252   hdb 5 rooms  99-year leasehold      2017.0       3.0        2.0
# 20253         condo           freehold      2023.0       4.0        4.0
#
#        size_sqft  ...   furnishing      available_unit_types total_num_units  \
# 0           1115  ...  unspecified                       NaN           116.0
# 1           1575  ...  unspecified       1, 2, 3, 4, 5, 6 br             NaN
# 2           3070  ...      partial     studio, 3, 4, 5, 6 br            56.0
# 3            958  ...      partial     studio, 1, 2, 3, 4 br           638.0
# 4            732  ...  unspecified  studio, 1, 2, 3, 4, 5 br           351.0
# ...          ...  ...          ...                       ...             ...
# 20249        635  ...  unspecified             1, 2, 3, 4 br           605.0
# 20250        883  ...  unspecified             1, 2, 3, 4 br           137.0
# 20251       1378  ...  unspecified  studio, 1, 2, 3, 4, 5 br           340.0
# 20252       1205  ...  unfurnished                2, 3, 4 br           402.0
# 20253       1378  ...      partial  studio, 1, 2, 3, 4, 5 br           340.0
#
#                                     property_details_url                 lat  \
# 0      https://www.99.co/singapore/hdb/866-yishun-str...          1.41439935
# 1      https://www.99.co/singapore/hdb/hdbserangoon-e...  1.3725968000000002
# 2      https://www.99.co/singapore/condos-apartments/...           1.2987726
# 3      https://www.99.co/singapore/condos-apartments/...           1.3123637
# 4      https://www.99.co/singapore/condos-apartments/...           1.2739587
# ...                                                  ...                 ...
# 20249  https://www.99.co/singapore/condos-apartments/...           1.3859375
# 20250  https://www.99.co/singapore/condos-apartments/...           1.3159484
# 20251  https://www.99.co/singapore/condos-apartments/...           1.3159611
# 20252  https://www.99.co/singapore/hdb/admiralty-flor...           1.4407533
# 20253  https://www.99.co/singapore/condos-apartments/...           1.3159611
#
#                       lng elevation          subzone  planning_area      price
# 0      103.83719568172816         0     yishun south         yishun   514500.0
# 1      103.87562460126242         0  serangoon north      serangoon   995400.0
# 2              103.895798         0      mountbatten  marine parade  8485000.0
# 3      103.80327091227252         0     farrer court    bukit timah  2626000.0
# 4      103.84363531310518         0            anson  downtown core  1764000.0
# ...                   ...       ...              ...            ...        ...
# 20249   103.8344656879244         0           tagore     ang mo kio  1050000.0
# 20250         103.8575892         0         lavender        kallang  2087400.0
# 20251          103.836848         0         moulmein         novena  4193700.0
# 20252         103.8066711         0   woodlands east      woodlands   754800.0
# 20253          103.836848         0         moulmein         novena  4178000.0
#
# [20254 rows x 21 columns]

# %%
df_train_aux = generate_auxiliary_data(df_train)
df_train_aux
# Out:
#                       lat                 lng  dist_meters_to_nearest_mrt  \
# 0              1.41439935  103.83719568172816                  573.566928
# 1      1.3725968000000002  103.87562460126242                 1728.895028
# 2               1.2987726          103.895798                 1315.256431
# 3               1.3123637  103.80327091227252                  723.885330
# 4               1.2739587  103.84363531310518                  370.021700
# ...                   ...                 ...                         ...
# 20249           1.3859375   103.8344656879244                  150.007415
# 20250           1.3159484         103.8575892                  442.631218
# 20251           1.3159611          103.836848                  422.130692
# 20252           1.4407533         103.8066711                  632.423139
# 20253           1.3159611          103.836848                  422.130692
#
#       nearest_mrt_code nearest_mrt_line  dist_meters_to_nearest_mall  \
# 0                 ns14               ns                   620.066152
# 1                 ne13               ne                   551.705560
# 2                  cc8               cc                   822.517804
# 3                 cc20               cc                   907.845081
# 4                 ew15               ew                   428.960960
# ...                ...              ...                          ...
# 20249              te5               te                  2008.342040
# 20250              ne8               ne                   532.359497
# 20251             dt11               dt                   765.085896
# 20252             ns10               ns                   602.359111
# 20253             dt11               dt                   765.085896
#
#        nearest_mall_index  dist_meters_to_nearest_commercial_centre  \
# 0                     103                               3342.136748
# 1                     113                               2388.871680
# 2                      72                               2159.421533
# 3                      19                               1605.948865
# 4                      51                               1864.412456
# ...                   ...                                       ...
# 20249                  94                               3165.626279
# 20250                  11                               1642.455781
# 20251                  58                                855.544220
# 20252                  89                               2155.912402
# 20253                  58                                855.544220
#
#        nearest_commercial_centre_index  dist_meters_to_nearest_primary_school  \
# 0                                    2                             274.527938
# 1                                   31                             122.819531
# 2                                   30                             888.509938
# 3                                   28                            1086.151844
# 4                                    0                             464.744201
# ...                                ...                                    ...
# 20249                               18                             791.022417
# 20250                               29                             657.243186
# 20251                               29                             366.210022
# 20252                               19                             230.110808
# 20253                               29                             366.210022
#
#        nearest_primary_school_index  dist_meters_to_nearest_secondary_school  \
# 0                                99                               182.562453
# 1                               130                               290.331371
# 2                               147                               891.530935
# 3                                97                              1102.475585
# 4                                20                              1542.648854
# ...                             ...                                      ...
# 20249                             5                              1029.960484
# 20250                            67                               997.602605
# 20251                             6                               430.393277
# 20252                            62                               707.623180
# 20253                             6                               430.393277
#
#        nearest_secondary_school_index
# 0                                  88
# 1                                  15
# 2                                  32
# 3                                 100
# 4                                  89
# ...                               ...
# 20249                              97
# 20250                              13
# 20251                               4
# 20252                               0
# 20253                               4
#
# [20254 rows x 13 columns]

# %%
df_test = pd.read_csv(Path(data_dir, "test.csv"))
df_test_aux = generate_auxiliary_data(df_test)
df_test_aux
# Out:
#            lat         lng  dist_meters_to_nearest_mrt nearest_mrt_code  \
# 0     1.344334  103.878690                  261.672594             cc12
# 1     1.380281  103.943878                 1001.264290              ew1
# 2     1.294668  103.850074                  251.350375              cc2
# 3     1.373120  103.746094                 1367.323437              ns4
# 4     1.341468  103.849047                  273.515978             ns18
# ...        ...         ...                         ...              ...
# 6995  1.249534  103.844281                 2992.831027             ew15
# 6996  1.332492  103.800004                  389.150989              dt7
# 6997  1.294106  103.836735                  729.462991             ns23
# 6998  1.303736  103.911438                 1920.516380              ew6
# 6999  1.302770  103.869435                  656.923572              cc6
#
#      nearest_mrt_line  dist_meters_to_nearest_mall  nearest_mall_index  \
# 0                  cc                   985.874655                 110
# 1                  ew                   281.936655                  86
# 2                  cc                   212.685809                   7
# 3                  ns                   501.765017                 133
# 4                  ns                  1009.165929                  21
# ...               ...                          ...                 ...
# 6995               ew                  2885.355551                 142
# 6996               dt                   965.822466                 156
# 6997               ns                   532.653630                  17
# 6998               ew                   729.699795                  76
# 6999               cc                   382.422444                  74
#
#       dist_meters_to_nearest_commercial_centre  \
# 0                                  1044.920854
# 1                                  1435.511147
# 2                                   157.232207
# 3                                  4504.563672
# 4                                   985.918261
# ...                                        ...
# 6995                               4272.197274
# 6996                               3081.254261
# 6997                               1527.283142
# 6998                               2555.480675
# 6999                               2252.831259
#
#       nearest_commercial_centre_index  dist_meters_to_nearest_primary_school  \
# 0                                  31                             341.056419
# 1                                  15                            1078.101901
# 2                                  37                             343.739518
# 3                                   1                             702.141804
# 4                                  32                             418.716281
# ...                               ...                                    ...
# 6995                                0                            2946.737990
# 6996                               28                             743.925796
# 6997                               37                            1444.051119
# 6998                               30                             147.133722
# 6999                               37                            1355.591932
#
#       nearest_primary_school_index  dist_meters_to_nearest_secondary_school  \
# 0                               88                               343.615356
# 1                               93                              1396.610341
# 2                               22                               562.723759
# 3                               34                              1062.566045
# 4                               79                               360.715437
# ...                            ...                                      ...
# 6995                            20                              3861.603350
# 6996                           126                               322.085215
# 6997                             3                               866.888397
# 6998                           148                               749.160547
# 6999                           139                              1453.624324
#
#       nearest_secondary_school_index
# 0                                 71
# 1                                 55
# 2                                109
# 3                                122
# 4                                  9
# ...                              ...
# 6995                              29
# 6996                              79
# 6997                              89
# 6998                              25
# 6999                              41
#
# [7000 rows x 13 columns]

# %% [markdown]
# ### Save the results

# %%
df_train_aux = df_train_aux.drop(['lat', 'lng'], axis=1)
# Out:
#        dist_meters_to_nearest_mrt nearest_mrt_code nearest_mrt_line  \
# 0                      573.566928             ns14               ns
# 1                     1728.895028             ne13               ne
# 2                     1315.256431              cc8               cc
# 3                      723.885330             cc20               cc
# 4                      370.021700             ew15               ew
# ...                           ...              ...              ...
# 20249                  150.007415              te5               te
# 20250                  442.631218              ne8               ne
# 20251                  422.130692             dt11               dt
# 20252                  632.423139             ns10               ns
# 20253                  422.130692             dt11               dt
#
#        dist_meters_to_nearest_mall  nearest_mall_index  \
# 0                       620.066152                 103
# 1                       551.705560                 113
# 2                       822.517804                  72
# 3                       907.845081                  19
# 4                       428.960960                  51
# ...                            ...                 ...
# 20249                  2008.342040                  94
# 20250                   532.359497                  11
# 20251                   765.085896                  58
# 20252                   602.359111                  89
# 20253                   765.085896                  58
#
#        dist_meters_to_nearest_commercial_centre  \
# 0                                   3342.136748
# 1                                   2388.871680
# 2                                   2159.421533
# 3                                   1605.948865
# 4                                   1864.412456
# ...                                         ...
# 20249                               3165.626279
# 20250                               1642.455781
# 20251                                855.544220
# 20252                               2155.912402
# 20253                                855.544220
#
#        nearest_commercial_centre_index  dist_meters_to_nearest_primary_school  \
# 0                                    2                             274.527938
# 1                                   31                             122.819531
# 2                                   30                             888.509938
# 3                                   28                            1086.151844
# 4                                    0                             464.744201
# ...                                ...                                    ...
# 20249                               18                             791.022417
# 20250                               29                             657.243186
# 20251                               29                             366.210022
# 20252                               19                             230.110808
# 20253                               29                             366.210022
#
#        nearest_primary_school_index  dist_meters_to_nearest_secondary_school  \
# 0                                99                               182.562453
# 1                               130                               290.331371
# 2                               147                               891.530935
# 3                                97                              1102.475585
# 4                                20                              1542.648854
# ...                             ...                                      ...
# 20249                             5                              1029.960484
# 20250                            67                               997.602605
# 20251                             6                               430.393277
# 20252                            62                               707.623180
# 20253                             6                               430.393277
#
#        nearest_secondary_school_index
# 0                                  88
# 1                                  15
# 2                                  32
# 3                                 100
# 4                                  89
# ...                               ...
# 20249                              97
# 20250                              13
# 20251                               4
# 20252                               0
# 20253                               4
#
# [20254 rows x 11 columns]

# %%
df_train_aux.to_csv("raw_data/train_auxiliary_data.csv")

# %%
df_test_aux = df_test_aux.drop(['lat', 'lng'], axis=1)

# %%
df_test_aux.to_csv("raw_data/test_auxiliary_data.csv")
