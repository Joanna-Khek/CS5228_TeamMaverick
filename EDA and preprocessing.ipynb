# %% [markdown]
# ## Exploratory Data Analysis
# ### Load the training data

# %%
import pandas as pd

# %%
# Read the training data
X_train = pd.read_csv('cs5228-2022-semester-1-final-project/train.csv')

# %% [markdown]
# ### Initial feature removal
# Dropping the columns that are unlikely to be useful to the prediction of property prices.

# %%
# Drop the columns that are not useful in predicting prices (before EDA, based on the data description alone)
columns_to_drop = ['listing_id', 'title', 'address', 'property_name', 'available_unit_types', 'total_num_units', 'property_details_url']
X_train = X_train.drop(columns_to_drop, axis=1)
X_train.head()
# Out:
#   property_type             tenure  built_year  num_beds  num_baths  \
# 0   hdb 4 rooms                NaN      1988.0       3.0        2.0
# 1           hdb  99-year leasehold      1992.0       4.0        2.0
# 2         condo           freehold      2022.0       4.0        6.0
# 3         Condo           freehold      2023.0       3.0        2.0
# 4         condo  99-year leasehold      2026.0       2.0        1.0
#
#    size_sqft floor_level   furnishing       lat         lng  elevation  \
# 0       1115         NaN  unspecified  1.414399  103.837196          0
# 1       1575         NaN  unspecified  1.372597  103.875625          0
# 2       3070         low      partial  1.298773  103.895798          0
# 3        958         NaN      partial  1.312364  103.803271          0
# 4        732         NaN  unspecified  1.273959  103.843635          0
#
#            subzone  planning_area      price
# 0     yishun south         yishun   514500.0
# 1  serangoon north      serangoon   995400.0
# 2      mountbatten  marine parade  8485000.0
# 3     farrer court    bukit timah  2626000.0
# 4            anson  downtown core  1764000.0

# %%
print(f'There are {X_train.shape[0]} records in the training set.')
# Out:
# There are 20254 records in the training set.

# %% [markdown]
# ### Univariate analysis
# #### Numerical variables
# The summary statistics of numerical variables can be printed using the `describe()` function. Several problems are observed:
# - Missing values for several columns (see next section)
# - `built_year` should not exceed 2022, but a quarter of the data has value >= 2023, max value is 2028.
# - `size_sqft` should not be zero. The maximum value is unreasonable, indicating outliers.
# - For Singapore, (`lat`, `lng`) should be around (1.4, 103), but there are records that are outliers.
# - The column `elevation` has zero value for all records.
# - The target variable `price` has dirty records with zero value or impossibly high price.

# %%
# Print a summary table for numeric variables
X_train.describe()
# Out:
#          built_year      num_beds     num_baths     size_sqft           lat  \
# count  19332.000000  20174.000000  19820.000000  2.025400e+04  20254.000000
# mean    2010.833695      3.122931      2.643542  1.854364e+03      1.434282
# std       15.822803      1.281658      1.473835  1.354343e+04      1.558472
# min     1963.000000      1.000000      1.000000  0.000000e+00      1.239621
# 25%     2000.000000      2.000000      2.000000  8.070000e+02      1.307329
# 50%     2017.000000      3.000000      2.000000  1.119000e+03      1.329266
# 75%     2023.000000      4.000000      3.000000  1.528000e+03      1.372461
# max     2028.000000     10.000000     10.000000  1.496000e+06     69.486768
#
#                 lng  elevation         price
# count  20254.000000    20254.0  2.025400e+04
# mean     103.855356        0.0  5.228263e+06
# std        3.593441        0.0  2.779748e+08
# min      -77.065364        0.0  0.000000e+00
# 25%      103.806576        0.0  8.190000e+05
# 50%      103.841552        0.0  1.680000e+06
# 75%      103.881514        0.0  3.242400e+06
# max      121.023232        0.0  3.924243e+10

# %% [markdown]
# #### Categorical variables
# The code below prints the summary table for categorical variables. Several problems are observed:
# - problem 1...
# - problem 2...

# %%
# Print a summary table for categorical variables
X_train.describe(include='object')
# Out:
#        property_type             tenure floor_level   furnishing   subzone  \
# count          20254              18531        3508        20254     20141
# unique            39                 11          17            5       244
# top            condo  99-year leasehold        high  unspecified  moulmein
# freq            7905              11407        1674        14716       656
#
#        planning_area
# count          20141
# unique            43
# top      bukit timah
# freq            1320

# %% [markdown]
# #### Missing values
# Below shows the number of records with empty values for each column:
# - For `floor_level`, around 83% of training records are empty values
# - For `tenure`, around 9% of training records are empty values

# %%
print('Portion of empty values for each column:')
print(
    (X_train.shape[0] - X_train.describe(include='all').loc['count']) / X_train.shape[0])
# Out:
# Portion of empty values for each column:
# property_type         0.0
# tenure            0.08507
# built_year       0.045522
# num_beds          0.00395
# num_baths        0.021428
# size_sqft             0.0
# floor_level        0.8268
# furnishing            0.0
# lat                   0.0
# lng                   0.0
# elevation             0.0
# subzone          0.005579
# planning_area    0.005579
# price                 0.0
# Name: count, dtype: object

# %% [markdown]
# ### Data cleaning
# can do the data cleaning here
